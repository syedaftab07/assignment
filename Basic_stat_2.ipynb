# %%
import pandas as pd

# %%
#converting the data into suitable format
data =[1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]
df=pd.DataFrame(data,columns=['Durability'])
df
# Out:
#     Durability
# 0         1.13
# 1         1.55
# 2         1.43
# 3         0.92
# 4         1.25
# 5         1.36
# 6         1.32
# 7         0.85
# 8         1.07
# 9         1.48
# 10        1.20
# 11        1.33
# 12        1.18
# 13        1.22
# 14        1.29

# %%
#finding mean and standard deviation to calucate confidence interval
df.describe()
# Out:
#        Durability
# count   15.000000
# mean     1.238667
# std      0.193164
# min      0.850000
# 25%      1.155000
# 50%      1.250000
# 75%      1.345000
# max      1.550000

# %%
from scipy import stats

# %%
conf =stats.norm.interval(0.99,1.238,0.193)
print("Confidence interval for 99% is ",conf)
# Out:
# Confidence interval for 99% is  (0.7408649444150621, 1.7351350555849379)

# %%
conf=stats.norm.interval(0.99,1.238,0.2)
print("Confidence interval for 99% if Standard deviation was 0.2",conf)
# Out:
# Confidence interval for 99% if Standard deviation was 0.2 (0.7228341392902199, 1.75316586070978)
